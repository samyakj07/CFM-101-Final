# %%
#These are the libraries you can use.  You may add any libraries directy related to threading if this is a direction
#you wish to go (this is not from the course, so it's entirely on you if you wish to use threading).  Any
#further libraries you wish to use you must email me, james@uwaterloo.ca, for permission.

from IPython.display import display, Math, Latex

import pandas as pd
import numpy as np
import numpy_financial as npf
import yfinance as yf
import matplotlib.pyplot as plt
import random
from datetime import datetime

# %% [markdown]
# ## Group Assignment
# ### Team Number: XX
# ### Team Member Names:
# ### Team Strategy Chosen: __________(Market Beat, Market Meet, Risk-Free)

# %%
tickers = pd.read_csv('Tickers_Example.csv', header=None)
tickers = tickers.rename(columns={0:"Ticker"})

# %%
start_date = '2024-10-01'
end_date = '2025-09-30'
min_volume = 5000
min_trading_days=18

'''
def filter_by_avg_dail_volume(prices_dict, min_volume, min_trading_days):

    passing_tickers = []
    avg_volumes = {}

    for ticker, df in prices_dict.items():

        df = df.loc[start_date:end_date].copy()

        days_per)month = df.groupby
 '''
# Out:
# '\ndef filter_by_avg_dail_volume(prices_dict, min_volume, min_trading_days):\n\n    passing_tickers = []\n    avg_volumes = {}\n\n    for ticker, df in prices_dict.items():\n\n        df = df.loc[start_date:end_date].copy()\n\n        days_per)month = df.groupby\n '

# %% [markdown]
# Filter:
# 1) Is the ticker listed? (check for delistinng)
# 2) Check for CAD/USD
# 3) filter by trading days and check volume

# %%
def enough_days(vol):
    return len(vol) >=18



for ticker in tickers['Ticker']:
    
    volume = yf.Ticker(ticker).history(start=start_date, end=end_date)[['Volume']]

    volume['Year-Month'] = volume.index.to_period('M')
    #print(volume.to_markdown())
    
    valid_months = volume.groupby(volume['Year-Month']).filter(enough_days)
    #print(valid_months.to_markdown())

    avg_daily = valid_months['Volume'].mean()
    print(avg_daily)
# Out:
# C:\Users\jacka\AppData\Local\Temp\ipykernel_24348\3388455425.py:10: UserWarning: Converting to PeriodArray/Index representation will drop timezone information.
#   volume['Year-Month'] = volume.index.to_period('M')
# C:\Users\jacka\AppData\Local\Temp\ipykernel_24348\3388455425.py:10: UserWarning: Converting to PeriodArray/Index representation will drop timezone information.
#   volume['Year-Month'] = volume.index.to_period('M')
# C:\Users\jacka\AppData\Local\Temp\ipykernel_24348\3388455425.py:10: UserWarning: Converting to PeriodArray/Index representation will drop timezone information.
#   volume['Year-Month'] = volume.index.to_period('M')
# C:\Users\jacka\AppData\Local\Temp\ipykernel_24348\3388455425.py:10: UserWarning: Converting to PeriodArray/Index representation will drop timezone information.
#   volume['Year-Month'] = volume.index.to_period('M')
# 53844303.212851405
# 6362559.036144578
# 6189107.630522088
# 3444718.875502008
# $AGN: possibly delisted; no timezone found
# ...

# %% [markdown]
# ## Contribution Declaration
#
# The following team members made a meaningful contribution to this assignment:
#
# Insert Names Here.
